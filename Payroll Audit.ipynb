# %%
from IPython.display import Image
Image(filename='logo.png')

# %%
# Payroll Comparison
#### Netpay Comparison of Employee in the month of February and March

# %%
# data manipulation
import pandas as pd
import numpy as np

# data visualization libraries
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# apply some cool styling
plt.style.use("ggplot")
rcParams['figure.figsize'] = (12,  6)

# %% [markdown]
# ### OBJECTIVE:
#
# The objective of this project is to obtain difference in the Net pay of the employee and to trace out the reason for difference
#
#
# #### ASSERTIONS:-  Accuracy
#
# ### Work Flow
#
# * Obtained a list of all employees with their base salaries and bonus payments for the period in excel.
# * Ensured completenes of the list with system / Work paper with reconcilation of employees from last year to this year.
# * Ensured all figures are numbers not text , converted into numbers for analysis.
# * Ensured none of the data columns have empty cells.
# * Provided name of the excel/csv file in input section.
# * Provided Columns headings to compare in x and y lablels

# %% [markdown]
# ### Inputs Section : CSV file name, names of the columns , headers

# %%
feb_data = pd.read_csv('AI_Feb_Data.csv')
mar_data = pd.read_csv('AI_March_Data.csv')
diff_data = pd.read_csv('Net_Pay_difference.csv')
print(f"Number of rows: {df.shape[0]}\nNumber of columns: {df.shape[1]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10792\1969328913.py in <module>
#       2 mar_data = pd.read_csv('AI_March_Data.csv')
#       3 diff_data = pd.read_csv('Net_Pay_difference.csv')
# ----> 4 print(f"Number of rows: {df.shape[0]}\nNumber of columns: {df.shape[1]}")
#
# NameError: name 'df' is not defined

# %%
#To understand the data type and information about data

feb_data.info()
mar_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Columns: 227 entries, F002 to F221
# dtypes: object(227)
# memory usage: 2.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Columns: 112 entries, Employee Number to Net Pay (Total)
# dtypes: float64(76), int64(31), object(5)
# memory usage: 1.3+ MB

# %%
# Check for Duplication

data.nunique()
# Out:
# F002    1502
# F003       3
# F004    1219
# F005    1219
# F006    1195
#         ...
# F217       3
# F218       3
# F219       4
# F220       4
# F221       3
# Length: 227, dtype: int64

# %%
for col in data.columns:
    print(col)
# Out:
# F002
# F003
# F004
# F005
# F006
# F007
# F008
# F009
# Region1
# Unnamed: 9
# Unnamed: 10
# Region2
# Unnamed: 12
# Unnamed: 13
# AllRegion
# F010
# F011
# F012
# F013
# F014
# F015
# F016
# F017
# F018
# F019
# F020
# F021
# F022
# F023
# F024
# F025
# F026
# F027
# F028
# F029
# F030
# F031
# F032
# F033
# F034
# F035
# F036
# F037
# F038
# F039
# F040
# F041
# F042
# F043
# F044
# F045
# F046
# F047
# F048
# F049
# F050
# F051
# F052
# F053
# F054
# F055
# F056
# F057
# F058
# F059
# F060
# F061
# F062
# F063
# F064
# F065
# F066
# F067
# F068
# F069
# F070
# F071
# F072
# F073
# F074
# F075
# F076
# F077
# F078
# F079
# F080
# F081
# F082
# F083
# F084
# F085
# F086
# F087
# F088
# F089
# F090
# F091
# F092
# F093
# F094
# F095
# F096
# F097
# F098
# F099
# F100
# F101
# F102
# F103
# F104
# F105
# F106
# F107
# F108
# F109
# F110
# F111
# F112
# F113
# F114
# F115
# F116
# F117
# F118
# F119
# F120
# F121
# F122
# F123
# F124
# F125
# F126
# F127
# F128
# F129
# F130
# F131
# ...

# %%
# Check the NUll Values
data.isnull().sum()
# Out:
# F002    0
# F003    0
# F004    1
# F005    1
# F006    1
#        ..
# F217    0
# F218    0
# F219    0
# F220    0
# F221    0
# Length: 227, dtype: int64

# %%
plt.rcParams['figure.figsize'] = [20,12]
plt.rcParams['font.sans-serif'] = ['Tahoma', 'DejaVu Sans',
                               'Lucida Grande', 'Verdana']
plt.rcParams['font.size'] = 8
plt.rcParams['figure.dpi'] = 200
plt.style.use('ggplot')
fig, ax = plt.subplots()


my_scatter_plot = ax.scatter(
data[xlabel], #x values
data[ylabel] # y values
# c = 'r',marker='o', s = 20
    

)

ax.set_xlabel(xlabel, color= 'navy', fontsize=10, fontweight = 'bold')
ax.set_ylabel(ylabel,color= 'navy', fontsize=10,fontweight = 'bold')

### Set your title here 
ax.set_title("Salary and Bonus Relationship",color= 'darkgreen', fontsize=16, fontweight='black')


for _, row in data[["Names",xlabel,ylabel]].iterrows():
    xy = row[[xlabel, ylabel]]
    xytext=  xy 
    ax.annotate(row["Names"], xy, xytext, fontsize=8)

#plt.savefig('enron.png')
my_scatter_plot.figsize=(10,6)
plt.savefig('payroll.png')

plt.show() #show the plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7548\2190290698.py in <module>
#       9
#      10 my_scatter_plot = ax.scatter(
# ---> 11 data[xlabel], #x values
#      12 data[ylabel] # y values
#      13 # c = 'r',marker='o', s = 20
#
# NameError: name 'xlabel' is not defined

# %% [markdown]
# ### OBSERVATION:
#
# Basen on work perfomed we noted that company policy is not  uniform in relation to bonus payment. Audit has identified following Person of Interest  for further investigations in relation to inappropriate use of authority and personal benefits.
#
# * Person A
# * Person B

# %% [markdown]
# ### CONCLUSION:
# Based on work performed and obervation noted ......
